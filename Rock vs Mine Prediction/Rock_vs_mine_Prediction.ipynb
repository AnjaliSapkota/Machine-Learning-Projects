# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjaliSapkota/Machine-Learning-Projects/blob/main/Rock%20vs%20Mine%20Prediction/Rock_vs_mine_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sonar_data = pd.read_csv('/content/drive/MyDrive/ml_datasets/Copy of sonar data.csv', header=None)

# %% [markdown]
# Data Preprocessing

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
print(sonar_data.isnull().sum())
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
print(sonar_data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Target variable analysis

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2   ...        57        58        59
# 60                                ...
# M   0.034989  0.045544  0.050720  ...  0.009060  0.008695  0.006930
# R   0.022498  0.030303  0.035951  ...  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,4))
sns.countplot(x=sonar_data[60])
plt.title('Target Variable Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
print(sonar_data.dtypes)
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
#        ...
# 56    float64
# 57    float64
# 58    float64
# 59    float64
# 60     object
# Length: 61, dtype: object

# %%
#Correlation matrix
plt.figure(figsize=(14,12))
sns.heatmap(sonar_data.iloc[:, :-1].corr(),
            cmap='coolwarm',
            center=0,
            cbar=True)

plt.title("Feature Correlation Matrix")
plt.show()

# %%
#BoxPlot- Outlier Detection
plt.figure(figsize=(20,6))
sns.boxplot(data=sonar_data.iloc[:, :-1])

plt.xticks(rotation=90)
plt.title("Feature Boxplots")
plt.show()

# %%
# Separate Features and Target
X = sonar_data.iloc[:, :-1]  # First 60 cols
y = sonar_data.iloc[:, -1]   #Last column

# %%
print(X)
print(y)
# Out:
#          0       1       2       3   ...      56      57      58      59
# 0    0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 1    0.0453  0.0523  0.0843  0.0689  ...  0.0140  0.0049  0.0052  0.0044
# 2    0.0262  0.0582  0.1099  0.1083  ...  0.0316  0.0164  0.0095  0.0078
# 3    0.0100  0.0171  0.0623  0.0205  ...  0.0050  0.0044  0.0040  0.0117
# 4    0.0762  0.0666  0.0481  0.0394  ...  0.0072  0.0048  0.0107  0.0094
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 204  0.0323  0.0101  0.0298  0.0564  ...  0.0034  0.0032  0.0062  0.0067
# 205  0.0522  0.0437  0.0180  0.0292  ...  0.0140  0.0138  0.0077  0.0031
# 206  0.0303  0.0353  0.0490  0.0608  ...  0.0034  0.0079  0.0036  0.0048
# 207  0.0260  0.0363  0.0136  0.0272  ...  0.0040  0.0036  0.0061  0.0115
#
# [208 rows x 60 columns]
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# ...

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, stratify=y, random_state=1)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %% [markdown]
# Model Training - Logistic Regression Model

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
# Accuracy on training data

X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

# %%
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.8342245989304813

# %%
# Accuracy on test data

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print("Accuracy on test data:", test_data_accuracy)
# Out:
# Accuracy on test data: 0.7619047619047619

# %% [markdown]
# Making a Prediction system

# %%
input_data= (0.0317,0.0956,0.1321,0.1408,0.1674,0.1710,0.0731,0.1401,0.2083,0.3513,0.1786,0.0658,0.0513,0.3752,0.5419,0.5440,0.5150,0.4262,0.2024,0.4233,0.7723,0.9735,0.9390,0.5559,0.5268,0.6826,0.5713,0.5429,0.2177,0.2149,0.5811,0.6323,0.2965,0.1873,0.2969,0.5163,0.6153,0.4283,0.5479,0.6133,0.5017,0.2377,0.1957,0.1749,0.1304,0.0597,0.1124,0.1047,0.0507,0.0159,0.0195,0.0201,0.0248,0.0131,0.0070,0.0138,0.0092,0.0143,0.0036,0.0103)

# chaing input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)
# Out:
# ['R']

# %%
if (prediction[0]=='R'):
  print('The object is a Rock')
else:
  print('The object is a mine')
# Out:
# The object is a Rock
